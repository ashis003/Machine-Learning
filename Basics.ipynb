# %% [markdown]
# <a href="https://colab.research.google.com/github/ashis003/Machine-Learning/blob/main/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
myDatasets = {
    'Name' : ['Mamma','Ashis','Surya','Bisso','Buchi','Ishmita'],
    'Roll no' : [17,16,1,3,7,5],
    'Fab_Subjects' : ['Hindi','Math','English','Science','Sanskrit','Arts'],
    'Marks' : [90,95,89,87,88,92]
}
df=pd.DataFrame(myDatasets)
df
# Out:
#       Name  Roll no Fab_Subjects  Marks
# 0    Mamma       17        Hindi     90
# 1    Ashis       16         Math     95
# 2    Surya        1      English     89
# 3    Bisso        3      Science     87
# 4    Buchi        7     Sanskrit     88
# 5  Ishmita        5         Arts     92

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 6

# %%
df.head()
# Out:
#     Name  Roll no Fab_Subjects  Marks
# 0  Mamma       17        Hindi     90
# 1  Ashis       16         Math     95
# 2  Surya        1      English     89
# 3  Bisso        3      Science     87
# 4  Buchi        7     Sanskrit     88

# %%
df.tail()
# Out:
#       Name  Roll no Fab_Subjects  Marks
# 1    Ashis       16         Math     95
# 2    Surya        1      English     89
# 3    Bisso        3      Science     87
# 4    Buchi        7     Sanskrit     88
# 5  Ishmita        5         Arts     92

# %%
df[2:5]
# Out:
#     Name  Roll no Fab_Subjects  Marks
# 2  Surya        1      English     89
# 3  Bisso        3      Science     87
# 4  Buchi        7     Sanskrit     88

# %%
df[:2]
# Out:
#     Name  Roll no Fab_Subjects  Marks
# 0  Mamma       17        Hindi     90
# 1  Ashis       16         Math     95

# %%
df[:3]
# Out:
#     Name  Roll no Fab_Subjects  Marks
# 0  Mamma       17        Hindi     90
# 1  Ashis       16         Math     95
# 2  Surya        1      English     89

# %%
df.columns
# Out:
# Index(['Name', 'Roll no', 'Fab_Subjects', 'Marks'], dtype='object')

# %%
df['Name']
# Out:
# 0      Mamma
# 1      Ashis
# 2      Surya
# 3      Bisso
# 4      Buchi
# 5    Ishmita
# Name: Name, dtype: object

# %% [markdown]
# # New Section

# %%
df[['Name','Marks']]
# Out:
#       Name  Marks
# 0    Mamma     90
# 1    Ashis     95
# 2    Surya     89
# 3    Bisso     87
# 4    Buchi     88
# 5  Ishmita     92

# %%
df[['Name','Marks','Roll no']]
# Out:
#       Name  Marks  Roll no
# 0    Mamma     90       17
# 1    Ashis     95       16
# 2    Surya     89        1
# 3    Bisso     87        3
# 4    Buchi     88        7
# 5  Ishmita     92        5

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Name','Marks']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['Name','Marks','Roll no']])
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       Name  Roll no Fab_Subjects  Marks
# 0    Mamma       17        Hindi     90
# 1    Ashis       16         Math     95
# 2    Surya        1      English     89
# 3    Bisso        3      Science     87
# 4    Buchi        7     Sanskrit     88
# 5  Ishmita        5         Arts     92

# %%
print(df)
# Out:
#       Name  Roll no Fab_Subjects  Marks
# 0    Mamma       17        Hindi     90
# 1    Ashis       16         Math     95
# 2    Surya        1      English     89
# 3    Bisso        3      Science     87
# 4    Buchi        7     Sanskrit     88
# 5  Ishmita        5         Arts     92

# %%
df['Marks'].max()
# Out:
# 95

# %%
df['Roll no'].min()
# Out:
# 1

# %%
df['Name'][df.Marks==df.Marks.max()]
# Out:
# 1    Ashis
# Name: Name, dtype: object

# %%
df['Roll no'][df.Marks==df.Marks.max()]
# Out:
# 1    16
# Name: Roll no, dtype: int64

# %%
df.head()
# Out:
#        index   Name  Roll no Fab_Subjects
# Marks
# 90         0  Mamma       17        Hindi
# 95         1  Ashis       16         Math
# 89         2  Surya        1      English
# 87         3  Bisso        3      Science
# 88         4  Buchi        7     Sanskrit

# %%
df.set_index('Marks',inplace=True)

# %%
df
# Out:
#        index     Name  Roll no Fab_Subjects
# Marks
# 90         0    Mamma       17        Hindi
# 95         1    Ashis       16         Math
# 89         2    Surya        1      English
# 87         3    Bisso        3      Science
# 88         4    Buchi        7     Sanskrit
# 92         5  Ishmita        5         Arts

# %%
df.loc[88]
# Out:
# index                  4
# Name               Buchi
# Roll no                7
# Fab_Subjects    Sanskrit
# Name: 88, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#    Roll no  Marks  index     Name Fab_Subjects
# 0       17     90      0    Mamma        Hindi
# 1       16     95      1    Ashis         Math
# 2        1     89      2    Surya      English
# 3        3     87      3    Bisso      Science
# 4        7     88      4    Buchi     Sanskrit
# 5        5     92      5  Ishmita         Arts

# %%
df.drop('level_0',axis=1,inplace=True)
df
# Out:
#    Marks  index     Name  Roll no Fab_Subjects
# 0     90      0    Mamma       17        Hindi
# 1     95      1    Ashis       16         Math
# 2     89      2    Surya        1      English
# 3     87      3    Bisso        3      Science
# 4     88      4    Buchi        7     Sanskrit
# 5     92      5  Ishmita        5         Arts

# %%
df.set_index('Roll no',inplace=True)
df
# Out:
#          Marks  index     Name Fab_Subjects
# Roll no
# 17          90      0    Mamma        Hindi
# 16          95      1    Ashis         Math
# 1           89      2    Surya      English
# 3           87      3    Bisso      Science
# 7           88      4    Buchi     Sanskrit
# 5           92      5  Ishmita         Arts

# %%
df.loc[7]
# Out:
# Marks                 88
# index                  4
# Name               Buchi
# Fab_Subjects    Sanskrit
# Name: 7, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#       Name  Roll no  Marks  index Fab_Subjects
# 0    Mamma       17     90      0        Hindi
# 1    Ashis       16     95      1         Math
# 2    Surya        1     89      2      English
# 3    Bisso        3     87      3      Science
# 4    Buchi        7     88      4     Sanskrit
# 5  Ishmita        5     92      5         Arts

# %%
df.set_index('Name',inplace=True)
df
# Out:
#          Roll no  Marks  index Fab_Subjects
# Name
# Mamma         17     90      0        Hindi
# Ashis         16     95      1         Math
# Surya          1     89      2      English
# Bisso          3     87      3      Science
# Buchi          7     88      4     Sanskrit
# Ishmita        5     92      5         Arts

# %%
df.loc['Ashis']
# Out:
# Roll no           16
# Marks             95
# index              1
# Fab_Subjects    Math
# Name: Ashis, dtype: object

# %%
df
# Out:
#       Name  Roll no  Marks  index Fab_Subjects
# 0    Mamma       17     90      0        Hindi
# 1    Ashis       16     95      1         Math
# 2    Surya        1     89      2      English
# 3    Bisso        3     87      3      Science
# 4    Buchi        7     88      4     Sanskrit
# 5  Ishmita        5     92      5         Arts
