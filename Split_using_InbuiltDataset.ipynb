# %% [markdown]
# <a href="https://colab.research.google.com/github/ashis003/Machine-Learning/blob/main/Split_using_InbuiltDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
from sklearn.datasets import load_breast_cancer

# %%
breast_cancer_data = load_breast_cancer()

# %%
type(breast_cancer_data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
df=pd.DataFrame(breast_cancer_data.data,columns=breast_cancer_data.feature_names)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
training_data = df.sample(frac=0.8,random_state=5)
testing_data=df.drop(training_data.index)

# %%
training_data.shape[0]
# Out:
# 455

# %%
training_data
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 28        15.300         25.27          102.40      732.4          0.10820
# 163       12.340         22.22           79.85      464.5          0.10120
# 123       14.500         10.89           94.28      640.7          0.11010
# 361       13.300         21.57           85.24      546.1          0.08582
# 549       10.820         24.21           68.89      361.6          0.08192
# ..           ...           ...             ...        ...              ...
# 266       10.600         18.95           69.28      346.4          0.09688
# 470        9.667         18.49           61.49      289.1          0.08946
# 473       12.270         29.97           77.42      465.4          0.07699
# 169       14.970         16.95           96.22      685.9          0.09855
# 36        14.250         21.72           93.63      633.0          0.09823
#
# ...

# %%
testing_data
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 5          12.45         15.70           82.57      477.1          0.12780
# 8          13.00         21.82           87.50      519.8          0.12730
# 13         15.85         23.95          103.70      782.7          0.08401
# 14         13.73         22.61           93.60      578.3          0.11310
# 16         14.68         20.13           94.74      684.5          0.09867
# ..           ...           ...             ...        ...              ...
# 542        14.74         25.42           94.70      668.6          0.08275
# 544        13.87         20.70           89.77      584.8          0.09578
# 550        10.86         21.48           68.51      360.5          0.07431
# 552        12.77         29.43           81.35      507.9          0.08276
# 556        10.16         19.59           64.73      311.7          0.10030
#
# ...
